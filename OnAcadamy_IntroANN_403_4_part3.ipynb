# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("lakshmi25npathi/imdb-dataset-of-50k-movie-reviews")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\MBAhmadi\AppData\Local\Programs\Python\Python312\Lib\site-packages\kagglehub\exceptions.py:66, in kaggle_api_raise_for_status(response, resource_handle)
#      65 try:
# ---> 66     response.raise_for_status()
#      67 except requests.HTTPError as e:
#
# File c:\Users\MBAhmadi\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://www.kaggle.com/api/v1/datasets/view/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews
#
# The above exception was the direct cause of the following exception:
#
# KaggleApiHTTPError                        Traceback (most recent call last)
# Cell In[8], line 4
# ...

# %%
# !mv /root/.cache/kagglehub/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews/versions/1/IMDB\ Dataset.csv IMDB_Dataset.csv
# Out:
# 'mv' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd

# %%
imdb_data = pd.read_csv("IMDB_Dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 imdb_data = pd.read_csv("IMDB_Dataset.csv")
#
# File c:\Users\MBAhmadi\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
imdb_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 imdb_data.head()
#
# NameError: name 'imdb_data' is not defined

# %%
imdb_data["review"][1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 imdb_data["review"][1]
#
# NameError: name 'imdb_data' is not defined

# %% [markdown]
# # Basic Stats

# %%
len(str(imdb_data["review"][0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 len(str(imdb_data["review"][0]))
#
# NameError: name 'imdb_data' is not defined

# %%
word_count = imdb_data["review"].apply(lambda x: len(str(x).split()))
unique_word_count = imdb_data["review"].apply(lambda x: len(set(str(x).split())))
char_count = imdb_data["review"].apply(lambda x: len(set(str(x))))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 word_count = imdb_data["review"].apply(lambda x: len(str(x).split()))
#       2 unique_word_count = imdb_data["review"].apply(lambda x: len(set(str(x).split())))
#       3 char_count = imdb_data["review"].apply(lambda x: len(set(str(x))))
#
# NameError: name 'imdb_data' is not defined

# %%
char_count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 char_count
#
# NameError: name 'char_count' is not defined
